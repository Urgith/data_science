# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('data.xlsx')

# %%
df = df.iloc[:, 1:]
df_size = df.shape[1]
size = df_size // 2 + 1

# %%
df = df.sort_values(f'ranking_{df_size // 2}')

# %%
df = df.iloc[:, 0:df_size:2]

# %%
sns.set_style('darkgrid')

for row in df.iterrows():
    plt.plot(range(1, size), row[1].values[1:])

plt.xticks(range(1, size, 2));

# %%
df2 = df.copy()

# %%
df2.iloc[:, 1:] = df2.iloc[:, 1:] / np.arange(1, size)

# %%
for row in df2.iterrows():
    plt.plot(range(1, size), row[1].values[1:])

plt.xticks(range(1, size, 2));

# %%
df.iloc[:, 1:] = df.iloc[:, 1:].cumsum(axis=1) / np.arange(1, size)

# %%
for row in df.iterrows():
    plt.plot(range(1, size), row[1].values[1:])

plt.xticks(range(1, size, 2));
