# %%
# 18.07.2025
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_excel('data.xlsx')
df
# Out:
#        #                Name  Fed  Rating  B-Year
# 0      1     Carlsen, Magnus  NOR    2839    1990
# 1      2    Nakamura, Hikaru  USA    2807    1987
# 2      3    Caruana, Fabiano  USA    2784    1992
# 3      4    Praggnanandhaa R  IND    2779    2005
# 4      5      Erigaisi Arjun  IND    2776    2003
# ..   ...                 ...  ...     ...     ...
# 96    97  Kryvoruchko, Yuriy  UKR    2633    1986
# 97    98      Korobov, Anton  UKR    2631    1985
# 98    99     Bacrot, Etienne  FRA    2631    1983
# 99   100      Safarli, Eltaj  AZE    2630    1992
# 100  101    Cheparinov, Ivan  BUL    2630    1986
#
# [101 rows x 5 columns]

# %%
grouped = df.groupby('Fed')['Rating']
new_df = grouped.max().sort_values(ascending=True)

# %%
new_df.plot.barh()

plt.grid(axis='x')
plt.xlim([2600, 2900])
plt.title('Highest rated player by country')
plt.ylabel('Country')
plt.xlabel('Rating')

plt.show()

# %%
new_df = df.groupby('B-Year')['Rating']
grouped = new_df.mean()
grouped.index = 2025 - grouped.index

# %%
grouped.plot.bar()
plt.ylim([2600, 2800])
plt.title('Average rating by age')
plt.ylabel('Mean rating')
plt.xlabel('Age')

plt.grid(axis='y')
plt.show()
