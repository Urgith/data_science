# %%
from bs4 import BeautifulSoup
import pandas as pd

# %%
with open('wikipedia_polska.txt', 'r', encoding='utf8') as file:
    text = file.read()

# %%
soup = BeautifulSoup(text, 'html.parser')

# %%
table = soup.find_all('table', class_='wikitable sortable jquery-tablesorter')

names = []
for element in table[0].find('thead').find('tr').find_all('th'):
    name = element.text.strip()

    if name:
        names.append(name)
    else:
        names.append('Nr')

names
# Out:
# ['Nr', 'Miasto', 'Liczba mieszkańców', 'Województwo']

# %%
data = []
for row in table[0].find('tbody').find_all('tr'):
    found = row.find_all('td')

    data.append([])
    for i, element in enumerate(found):
        text = element.text.strip()

        if i == 2:
            text = text.replace(' ', '')

        data[-1].append(text)

# %%
df = pd.DataFrame(data, columns=names)
df['Nr'] = df['Nr'].astype(int)
df['Liczba mieszkańców'] = df['Liczba mieszkańców'].astype(int)
df.set_index('Nr', inplace=True)

df
# Out:
#                  Miasto  Liczba mieszkańców          Województwo
# Nr
# 1              Warszawa             1861664          mazowieckie
# 2                Kraków              804237          małopolskie
# 3               Wrocław              674132         dolnośląskie
# 4                  Łódź              655279              łódzkie
# 5                Poznań              540146        wielkopolskie
# 6                Gdańsk              486492            pomorskie
# 7              Szczecin              390278   zachodniopomorskie
# 8                Lublin              330447            lubelskie
# 9             Bydgoszcz              328370   kujawsko-pomorskie
# 10            Białystok              292058            podlaskie
# 11             Katowice              279119              śląskie
# 12               Gdynia              242141            pomorskie
# 13          Częstochowa              207117              śląskie
# 14              Rzeszów              197536         podkarpackie
# 15                Radom              196918          mazowieckie
# 16                Toruń              195263   kujawsko-pomorskie
# 17            Sosnowiec              188151              śląskie
# 18               Kielce              183147       świętokrzyskie
# 19              Gliwice              170457              śląskie
# 20              Olsztyn              167844  warmińsko-mazurskie
# 21        Bielsko-Biała              166189              śląskie
# 22               Zabrze              154642              śląskie
# 23                Bytom              148687              śląskie
# 24         Zielona Góra              139132             lubuskie
# 25               Rybnik              131323              śląskie
# 26          Ruda Śląska              131062              śląskie
# 27                Opole              126300             opolskie
# 28                Tychy              122605              śląskie
# 29  Gorzów Wielkopolski              115847             lubuskie
# 30     Dąbrowa Górnicza              114148              śląskie
# 31               Elbląg              113195  warmińsko-mazurskie
# 32                Płock              111927          mazowieckie
# 33             Koszalin              105905   zachodniopomorskie
# 34               Tarnów              103515          małopolskie
# 35            Włocławek              101450   kujawsko-pomorskie
# 36              Chorzów              101184              śląskie
# 37            Wałbrzych              101082         dolnośląskie

# %%
df.to_excel('data.xlsx')
