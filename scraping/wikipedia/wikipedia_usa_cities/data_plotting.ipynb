# %%
# 20.07.2025
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import pandas as pd

# %%
df = pd.read_excel('data.xlsx')
df
# Out:
#     Rank                      Name     Region  Population
# 0      1                  New York  Northeast    19940274
# 1      2               Los Angeles       West    12927614
# 2      3                   Chicago    Midwest     9408576
# 3      4         Dallas–Fort Worth      South     8344032
# 4      5                   Houston      South     7796182
# 5      6                     Miami      South     6457988
# 6      7          Washington, D.C.      South     6436489
# 7      8                   Atlanta      South     6411149
# 8      9              Philadelphia  Northeast     6330422
# 9     10                   Phoenix       West     5186958
# 10    11                    Boston  Northeast     5025517
# 11    12  Riverside–San Bernardino       West     4744214
# 12    13             San Francisco       West     4648486
# 13    14                   Detroit    Midwest     4400578
# 14    15                   Seattle       West     4145494
# 15    16    Minneapolis–Saint Paul    Midwest     3757952
# 16    17      Tampa–St. Petersburg      South     3424560
# 17    18                 San Diego       West     3298799
# 18    19                    Denver       West     3052498
# 19    20                   Orlando      South     2940513

# %%
ax = sns.barplot(data=df, x='Name', y='Population', hue='Region')
ax.get_yaxis().set_major_formatter(
    mpl.ticker.FuncFormatter(lambda x, p: format(int(x), ','))
)

plt.title('Biggest US Cities')
plt.xlabel('City')

plt.xticks(rotation=90)
plt.grid(axis='y')
plt.show()
