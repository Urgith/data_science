# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.read_excel('data.xlsx')
df = df.iloc[:, 1:]
df
# Out:
#                              name  typ  level              zone       HP
# 0          Skrzynia Skarbów Duszy    3    103  Czerwone Wzgórza  1282649  \
# 1        Zmieszany Kaktus Owocowy    2    101   Rytualna Dolina   953843
# 2        Zmieszany Kaktus Iglasty    2    101   Rytualna Dolina   953843
# 3                        Jastrząb    0     15    Stepy Sascilii      946
# 4       Nietoperz-wampir Grobowca    2    103           unknown  8821044
# ...                           ...  ...    ...               ...      ...
# 10227             Siła Androliera    0      0           unknown      144
# 10228             Myśl Androliera    0      0           unknown      144
# 10229       Wzburzenie Androliera    0      0           unknown      144
# 10230  Uskrzydlony Pogromca Nr 45    0      0           unknown      144
# 10231  Uskrzydlony Pogromca Nr 90    0      0           unknown      144
#
#           MP    DMG    pAtk   mAtk  pCritRes  mCritRes    pdef    mdef     EP
# ...

# %%
df = df.sort_values(by='HP', ascending=False)
df
# Out:
#                            name  typ  level     zone          HP     MP
# 7002                    Zhargos    4    118  unknown  2147483647  47772  \
# 9489                     Kadnis    3    103  unknown   802716088  31504
# 9487                Nex z Enoch    3    103  unknown   801731351  31504
# 9486                Mroczny Ząb    3    103  unknown   704298359  31504
# 6955                        NaN    3    100      NaN   640598498  12633
# ...                         ...  ...    ...      ...         ...    ...
# 6467  Wszystkożerna Zębata Ryba    0      1  unknown        -517    104
# 6400                        NaN    0      1  unknown        -544    104
# 4613             Pogromca Nr 27    2     60  unknown       -1692   4195
# 3975                        NaN    0     40      NaN       -6808   2088
# 6802                        NaN    0     71  unknown      -23096   5215
#
#          DMG     pAtk    mAtk  pCritRes  mCritRes     pdef     mdef      EP
# ...

# %%
sns.set_style('darkgrid')
sns.scatterplot(data=df, x='level', y='HP', hue='typ')

plt.yscale('log')
