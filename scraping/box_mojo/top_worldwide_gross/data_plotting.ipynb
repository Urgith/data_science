# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_excel('data.xlsx')
df
# Out:
#       Rank                                       Title  Worldwide_gross  \
# 0        1                                      Avatar       2923710708
# 1        2                           Avengers: Endgame       2799439100
# 2        3                    Avatar: The Way of Water       2320250281
# 3        4                                     Titanic       2264812968
# 4        5  Star Wars: Episode VII - The Force Awakens       2071310218
# ...    ...                                         ...              ...
# 1995  1996                              The River Wild         94216343
# 1996  1997                               Dirty Grandpa         94073028
# 1997  1998                                     Ben-Hur         94061311
# 1998  1999                                    Blockers         94019120
# 1999  2000                            The Skeleton Key         93983911
#
#       Domestic_gross  Domestic %  Foreign_gross  Foreign %  Year
# ...

# %%
grouped = df.groupby('Year')['Worldwide_gross']
new_df = grouped.sum()

# %%
new_df.plot()

plt.ticklabel_format(style='plain')
plt.title('Worldwide Box Office by Year')
plt.ylabel('Box Office')
plt.grid()

plt.annotate(f'MAX: {max(new_df)}', xy=(2019, max(new_df)), xytext=(1975, 27500000000),
             arrowprops={'facecolor': 'black', 'shrink': 0.05})
plt.annotate(f'MIN: {new_df[2020]}', xy=(2020, new_df[2020]), xytext=(1965, 7500000000),
             arrowprops={'facecolor': 'black', 'shrink': 0.05})
# Out:
# Text(1965, 7500000000, 'MIN: 4788715859')
