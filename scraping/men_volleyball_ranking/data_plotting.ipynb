# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_excel('data.xlsx')
df = df[:20]
df
# Out:
#     Rank         Team   Score
# 0      1       Poland  396.13
# 1      2       France  365.40
# 2      3        Italy  357.46
# 3      4       Brazil  343.27
# 4      5        Japan  333.17
# 5      6          USA  332.30
# 6      7     Slovenia  317.04
# 7      8      Germany  274.74
# 8      9    Argentina  269.71
# 9     10         Cuba  259.11
# 10    11       Canada  255.39
# 11    12      Ukraine  234.65
# 12    13       Serbia  212.20
# 13    14         Iran  209.13
# 14    15     Bulgaria  194.19
# 15    16      Belgium  183.24
# 16    17  Netherlands  179.50
# 17    18      Finland  178.94
# 18    19      Türkiye  176.07
# 19    20      Romania  163.48

# %%
plt.bar(x=df['Team'], height=df['Score'])

plt.title('Volleyball TOP20')
plt.ylabel('Score')
plt.xlabel('Country')
plt.xticks(rotation=90)
plt.grid(axis='y')
plt.show()
