# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.read_excel('data.xlsx')
df
# Out:
#        Ranking                              Name   Type  Episodes      Start  \
# 0            1                Shingeki no Kyojin     TV      25.0 2013-04-01
# 1            2                        Death Note     TV      37.0 2006-10-01
# 2            3  Fullmetal Alchemist: Brotherhood     TV      64.0 2009-04-01
# 3            4                     One Punch Man     TV      12.0 2015-10-01
# 4            5                  Kimetsu no Yaiba     TV      26.0 2019-04-01
# ...        ...                               ...    ...       ...        ...
# 28610    28611              Obusu ni Hanataba wo    ONA       NaN 2025-07-01
# 28611    28612  Tsuihou Shiromadoushi Mini Anime    ONA       NaN 2025-07-01
# 28612    28613                       Tori no Uta  Music       1.0 2006-12-01
# 28613    28614                           The Fog  Music       1.0 2021-11-01
# 28614    28615                    Hamihadarigeri  Music       1.0 2009-05-01
#
#              End  Members  Score
# ...

# %%
mean = df['Score'].mean()
var = df['Score'].var()

# %%
plt.hist(df['Score'], bins=100)
plt.axvline(mean, color='red')
plt.annotate(text=f'Mean: {mean.round(4)}', xy=(6.5, 625), color='red', size=15)

plt.title('Scores distribution on MyAnimeList')
plt.ylabel('Number of scores')
plt.xlabel('Mean score')
plt.grid()
plt.show()

# %%
df_tv = df[df['Type'] == 'TV']

mean = df_tv['Score'].mean()
var = df_tv['Score'].var()

# %%
plt.hist(df_tv['Score'], bins=100)
plt.axvline(mean, color='red')
plt.annotate(text=f'Mean: {mean.round(4)}', xy=(7.5, 190), color='red', size=15)

plt.title('TV Scores distribution on MyAnimeList')
plt.ylabel('Number of scores')
plt.xlabel('Mean score')
plt.grid()
plt.show()

# %%
df = df[df['Type'] != 'Unknown']

sns.pointplot(data=df, x='Type', y='Score', linewidth=2)

plt.title('Score by Anime Type')
plt.ylabel('Mean Score')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %%
sns.boxplot(data=df, x='Type', y='Score', hue='Type')

plt.title('Score by Anime Type')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()
