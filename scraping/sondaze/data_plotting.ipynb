# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_excel('data.xlsx')
df = df.iloc[::-1]
df = df.reset_index(drop=True)
df = df.rolling(5).mean()
df
# Out:
#      Razem  Lewica      Ko  Pl2050    Psl    Pis  Konfederacja    Kkp     Td
# 0      NaN     NaN     NaN     NaN    NaN    NaN           NaN    NaN    NaN
# 1      NaN     NaN     NaN     NaN    NaN    NaN           NaN    NaN    NaN
# 2      NaN     NaN     NaN     NaN    NaN    NaN           NaN    NaN    NaN
# 3      NaN     NaN     NaN     NaN    NaN    NaN           NaN    NaN    NaN
# 4      NaN    7.70  30.200     NaN    NaN  33.86         6.740    NaN  16.26
# ..     ...     ...     ...     ...    ...    ...           ...    ...    ...
# 197   4.48    6.28  27.980     NaN    NaN  28.22        15.220  4.600    NaN
# 198   4.28    6.00  27.100     NaN    NaN  28.88        15.420  5.180    NaN
# 199   4.14    5.78  27.200     NaN    NaN  28.96        15.640  4.920    NaN
# 200   4.72    5.86  27.040   4.100  2.820  28.78        15.100  5.320    NaN
# 201   4.93    6.09  28.114   3.936  2.336  29.39        14.306  5.258    NaN
#
# [202 rows x 9 columns]

# %%
df.plot()

plt.title('Sondaże parlamentarne')
plt.ylabel('Poparcie (%)')
plt.xlabel('Numer sondażu')

plt.legend(loc='center', fontsize=6, bbox_to_anchor=(0.3, 0.4, 0.3, 0.3))
plt.show()
