# %%
# 19.07.2025
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('data.xlsx')
df
# Out:
#       Level    Experience
# 0         1             0
# 1         2           100
# 2         3           200
# 3         4           400
# 4         5           800
# ...     ...           ...
# 3495   3496  710914921000
# 3496   3497  711525497600
# 3497   3498  712136423700
# 3498   3499  712747699400
# 3499   3500  713359324800
#
# [3500 rows x 2 columns]

# %%
poly = np.polyfit(df['Level'], df['Experience'], 3)
poly
# Out:
# array([  16.66666667, -100.        ,  283.33333334, -200.00003135])

# %%
ax = df.plot('Level', 'Experience')
ax.get_yaxis().set_major_formatter(
    mpl.ticker.FuncFormatter(lambda x, p: format(int(x), ','))
)
x = df['Level']
plt.plot(x, x**3*poly[0] + x**2*poly[1] + x*poly[2] + poly[3])

plt.title('Tibia total_exp nedded to reach Level')
plt.ylabel('Experience')
plt.xlabel('Level')

plt.grid()
plt.show()

# %%
df['Diff_Experience'] = df['Experience'].diff()

# %%
poly = np.polyfit(df['Level'][1:], df['Diff_Experience'][1:], 2)
poly
# Out:
# array([  50.        , -250.        ,  400.00000007])

# %%
ax = df.plot('Level', 'Diff_Experience')
ax.get_yaxis().set_major_formatter(
    mpl.ticker.FuncFormatter(lambda x, p: format(int(x), ','))
)
x = df['Level'][1:]
plt.plot(x, x**2*poly[0] + x*poly[1] + poly[2])

plt.title('Exp nedded to gain 1 Level')
plt.ylabel('Experience')
plt.xlabel('Level')

plt.grid()
plt.show()
