# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_excel('data.xlsx')
df
# Out:
#       Level    Experience
# 0         1             0
# 1         2           100
# 2         3           200
# 3         4           400
# 4         5           800
# ...     ...           ...
# 3495   3496  710914921000
# 3496   3497  711525497600
# 3497   3498  712136423700
# 3498   3499  712747699400
# 3499   3500  713359324800
#
# [3500 rows x 2 columns]

# %%
plt.plot(df['Level'], df['Experience'])

plt.title('Tibia total_exp nedded to reach Level')
plt.ylabel('Experience')
plt.xlabel('Level')

plt.ticklabel_format(style='plain')
plt.grid()
plt.show()

# %%
df['Diff'] = df['Experience'].diff()
# Out:
# 0               NaN
# 1             100.0
# 2             100.0
# 3             200.0
# 4             400.0
#            ...
# 3495    610227200.0
# 3496    610576600.0
# 3497    610926100.0
# 3498    611275700.0
# 3499    611625400.0
# Name: Diff, Length: 3500, dtype: float64

# %%
plt.plot(df['Level'], df['Diff'])

plt.title('Exp nedded to gain 1 Level')
plt.ylabel('Experience')
plt.xlabel('Level')

plt.ticklabel_format(style='plain')
plt.grid()
plt.show()
