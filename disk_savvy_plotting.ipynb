# %%
# 01.09.2025
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_excel('disk_savvy.xlsx')
data
# Out:
#           date      time   files  disk_space
# 0   2022-04-15  14:29:52    7658       94.96
# 1   2022-04-15  18:07:39   10524      190.21
# 2   2022-04-15  18:09:04   12661      306.96
# 3   2022-04-15  18:10:27   15813      368.45
# 4   2022-04-15  18:11:12   16531      388.04
# ..         ...       ...     ...         ...
# 863 2025-08-26  13:10:17  189516     7310.00
# 864 2025-08-27  12:43:42  189446     7310.00
# 865 2025-08-28  12:19:41  189988     7310.00
# 866 2025-08-29  12:58:25  189300     7300.00
# 867 2025-09-01  12:31:32  189638     7300.00
#
# [868 rows x 4 columns]

# %%
plt.plot(data.date, data.disk_space)

plt.xticks(rotation=45)
plt.grid()

plt.title('Python Packages Storage by Time')
plt.xlabel('Date')
plt.ylabel('MB of Storage')

plt.show()

# %%
plt.plot(data.date, data.files)

plt.xticks(rotation=45)
plt.grid()

plt.title('Python Packages Files')
plt.xlabel('Date')
plt.ylabel('Number of Files')

plt.show()
