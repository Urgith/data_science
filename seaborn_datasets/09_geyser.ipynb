# %%
import seaborn as sns

# %%
df = sns.load_dataset('geyser')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 272 entries, 0 to 271
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   duration  272 non-null    float64
#  1   waiting   272 non-null    int64
#  2   kind      272 non-null    object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 6.5+ KB

# %%
df
# Out:
#      duration  waiting   kind
# 0       3.600       79   long
# 1       1.800       54  short
# 2       3.333       74   long
# 3       2.283       62  short
# 4       4.533       85   long
# ..        ...      ...    ...
# 267     4.117       81   long
# 268     2.150       46  short
# 269     4.417       90   long
# 270     1.817       46  short
# 271     4.467       74   long
#
# [272 rows x 3 columns]

# %%
sns.set_style('darkgrid')

# %%
sns.swarmplot(data=df, y='waiting', hue='kind')
# Out:
# <AxesSubplot:ylabel='waiting'>

# %% [markdown]
# Na wykresie powyżej łatwo rozdzielić te wybuchy, na które czeka się dłużej, od tych na które czeka się krócej. Wygląda na to, że wartość graniczna to 67.5 sekund.

# %%
sns.swarmplot(data=df, y='duration', hue='kind')
# Out:
# <AxesSubplot:ylabel='duration'>

# %% [markdown]
# Podział na długie i krótkie wybuchy gejzerów jest wyraźnie widoczny.

# %%
sns.scatterplot(x='duration', y='waiting', hue='kind', data=df)
# Out:
# <AxesSubplot:xlabel='duration', ylabel='waiting'>

# %% [markdown]
# Poza tym im gejzer rzadziej wybucha, tym dłużej trwa sam wybuch. Zauwazyć to można zwracając uwagę na fakt, że nie ma gejzerów, które szybko wybuchają i długo trwają, ani takich, które krótko trwają i rzadko wybuchają.

# %%
sns.regplot(x='waiting', y='duration', data=df)
# Out:
# <AxesSubplot:xlabel='waiting', ylabel='duration'>

# %% [markdown]
# Na wykresie powyżej widać, że im dłuzej czeka się na wybuch, tym dłuży jest sam wybuch.
