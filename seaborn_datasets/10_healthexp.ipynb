# %%
import seaborn as sns

# %%
df = sns.load_dataset('healthexp')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 274 entries, 0 to 273
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             274 non-null    int64
#  1   Country          274 non-null    object
#  2   Spending_USD     274 non-null    float64
#  3   Life_Expectancy  274 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 8.7+ KB

# %%
df
# Out:
#      Year        Country  Spending_USD  Life_Expectancy
# 0    1970        Germany       252.311             70.6
# 1    1970         France       192.143             72.2
# 2    1970  Great Britain       123.993             71.9
# 3    1970          Japan       150.437             72.0
# 4    1970            USA       326.961             70.9
# ..    ...            ...           ...              ...
# 269  2020        Germany      6938.983             81.1
# 270  2020         France      5468.418             82.3
# 271  2020  Great Britain      5018.700             80.4
# 272  2020          Japan      4665.641             84.7
# 273  2020            USA     11859.179             77.0
#
# [274 rows x 4 columns]

# %%
df['Country'].value_counts()
# Out:
# Country
# Japan            51
# USA              51
# Germany          50
# Canada           44
# Great Britain    43
# France           35
# Name: count, dtype: int64

# %%
sns.set_style('darkgrid')

# %%
for country in df['Country'].unique():
    data = df[df['Country'] == country]
    sns.lineplot(x='Year', y='Life_Expectancy', data=data, label=country)

# %% [markdown]
# Przewidywana długość życia w Niemczech, Francji, Wielkiej Brytanii, Japonii, Stanach Zjednoczonych oraz Kanadzie w latach 1970-2019 znacząco wzrosła.

# %%
for country in df['Country'].unique():
    data = df[df['Country'] == country]
    sns.lineplot(x='Year', y='Spending_USD', data=data, label=country)

# %% [markdown]
# W tym samym okresie wzrosły również wydatki na służbę zdrowia. Koszty leczenie  w Stanach wzrosły zauważalnie mocniej niż w reszcie państw.

# %%
data = df.groupby('Year').Life_Expectancy.mean()

# %%
data.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# Na wykresie powyżej widać, że oczekiwana długość życia, dla badanym państw z roku na rok rosła, wyjątkiem są lata 1972, 1980, 2004 oraz 2020.
