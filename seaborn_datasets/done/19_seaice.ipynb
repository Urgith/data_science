# %%
import seaborn as sns

# %%
df = sns.load_dataset('seaice')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13175 entries, 0 to 13174
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    13175 non-null  datetime64[ns]
#  1   Extent  13175 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 206.0 KB

# %%
df
# Out:
#             Date  Extent
# 0     1980-01-01  14.200
# 1     1980-01-03  14.302
# 2     1980-01-05  14.414
# 3     1980-01-07  14.518
# 4     1980-01-09  14.594
# ...          ...     ...
# 13170 2019-12-27  12.721
# 13171 2019-12-28  12.712
# 13172 2019-12-29  12.780
# 13173 2019-12-30  12.858
# 13174 2019-12-31  12.889
#
# [13175 rows x 2 columns]

# %%
sns.set_style('darkgrid')

# %%
sns.lineplot(x='Date', y='Extent', data=df)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Extent'>

# %% [markdown]
# Na wykresie powyżj widać lekki trend malejący.

# %%
df['month'] = df.Date.dt.month

# %%
sns.lineplot(x='month', y='Extent', data=df)
# Out:
# <AxesSubplot:xlabel='month', ylabel='Extent'>

# %% [markdown]
# Wykres powyżej pokauje nam, że największe wartości 'Extent' są w okolicahc marca, a najmniejsze we Wrześniu.

# %%
df['year'] = df.Date.dt.year

# %%
sns.regplot(x='year', y='Extent', data=df, scatter_kws={"color": "blue"}, line_kws={"color": "orange"})
# Out:
# <AxesSubplot:xlabel='year', ylabel='Extent'>

# %% [markdown]
# Na wykresie powyżej uwidocznion jest linia trendu, pokauje nam ona im wyższy rok tym mniejsza wartość.
